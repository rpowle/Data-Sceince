# %%
import pandas as pd

# %%
data=pd.read_excel ("D:\RAJ\AI\dataset\Sample - Superstore.xls")

# %%
type (data.OrderID)
# Out:
# pandas.core.series.Series

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
ser2=pd.Series(12)

# %%
ser2
# Out:
# 0    12
# dtype: int64

# %%
data.columns
# Out:
# Index(['Row ID', 'OrderID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.loc[data.Sales == 22.368, ["Region","Sales","Category"]]
# Out:
# Empty DataFrame
# Columns: [Region, Sales, Category]
# Index: []

# %%
data=data.assign(tax = data.Sales * 0.10)
#df = pd.DataFrame({'temp_c': [17.0, 25.0]},

# %%
data.head(2)
# Out:
#    Row ID         OrderID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  South
# 1   Claire Gute  Consumer  United States  Henderson  ...  South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
#
#    Discount    Profit     tax
# 0       0.0   41.9136  26.196
# 1       0.0  219.5820  73.194
#
# [2 rows x 22 columns]

# %%
data.columns
# Out:
# Index(['Row ID', 'OrderID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'tax'],
#       dtype='object')

# %%
data1=data[["OrderID", "Segment","Country"]]

# %%
data1.head(2)
# Out:
#           OrderID   Segment        Country
# 0  CA-2016-152156  Consumer  United States
# 1  CA-2016-152156  Consumer  United States

# %%
data1.drop(["OrderID"],axis=1)
#df.drop(['B', 'C'], axis=1)
# Out:
#         Segment        Country
# 0      Consumer  United States
# 1      Consumer  United States
# 2     Corporate  United States
# 3      Consumer  United States
# 4      Consumer  United States
# ...         ...            ...
# 9989   Consumer  United States
# 9990   Consumer  United States
# 9991   Consumer  United States
# 9992   Consumer  United States
# 9993   Consumer  United States
#
# [9994 rows x 2 columns]

# %%
data.sort_values(by='Category', ascending=False)
# Out:
#       Row ID         OrderID Order Date  Ship Date       Ship Mode  \
# 2445    2446  CA-2016-146934 2016-05-22 2016-05-27  Standard Class
# 5800    5801  CA-2014-123225 2014-07-11 2014-07-14     First Class
# 2464    2465  CA-2017-148691 2017-12-03 2017-12-09  Standard Class
# 8559    8560  CA-2016-132829 2016-12-23 2016-12-26    Second Class
# 8560    8561  CA-2016-132829 2016-12-23 2016-12-26    Second Class
# ...      ...             ...        ...        ...             ...
# 3831    3832  US-2015-111927 2015-11-14 2015-11-19  Standard Class
# 3834    3835  CA-2014-105984 2014-11-24 2014-11-24        Same Day
# 8068    8069  US-2015-160563 2015-10-20 2015-10-24  Standard Class
# 8070    8071  CA-2017-151750 2017-01-01 2017-01-05  Standard Class
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
#
#      Customer ID     Customer Name    Segment        Country           City  \
# 2445    AF-10870      Art Ferguson   Consumer  United States        Passaic
# ...

# %%
data.sort_values(by=['Country', "Sales"], ascending=(False, True))
#sort_values(["b", "c"], ascending = (False, True))
#Country,Sales
# Out:
#       Row ID         OrderID Order Date  Ship Date       Ship Mode  \
# 4101    4102  US-2017-102288 2017-06-19 2017-06-23  Standard Class
# 9292    9293  CA-2017-124114 2017-03-02 2017-03-02        Same Day
# 8658    8659  CA-2016-168361 2016-06-21 2016-06-25  Standard Class
# 4711    4712  CA-2014-112403 2014-03-31 2014-03-31        Same Day
# 2106    2107  US-2014-152723 2014-09-26 2014-09-26        Same Day
# ...      ...             ...        ...        ...             ...
# 4190    4191  CA-2017-166709 2017-11-17 2017-11-22  Standard Class
# 2623    2624  CA-2017-127180 2017-10-22 2017-10-24     First Class
# 8153    8154  CA-2017-140151 2017-03-23 2017-03-25     First Class
# 6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
# 2697    2698  CA-2014-145317 2014-03-18 2014-03-23  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 4101    ZC-21910  Zuschuss Carroll     Consumer  United States        Houston
# ...

# %%
#f.groupby(['Animal']).mean()
      #  Max Speed

# %%
data.columns
# Out:
# Index(['Row ID', 'OrderID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'tax'],
#       dtype='object')

# %%
data.head()
data1.groupby('')
# Out:
# <bound method DataFrame.groupby of       Row ID         OrderID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
data1.groupby('Segment')

# %%
data.OrderID.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: OrderID, Length: 9994, dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   OrderID        9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...
